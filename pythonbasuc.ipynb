# %%
import sklearn

# %%
import cv2
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-10-c8ec22b3e787> in <module>
# ----> 1 import cv2
#
# ModuleNotFoundError: No module named 'cv2'

# %%
# !pip install opencv
# Out:
# Unable to create process using 'C:\Users\Neha Dubey\anaconda3\python.exe "C:\Users\Neha Dubey\anaconda3\Scripts\pip-script.py" install opencv'

# %%
import cv2
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-4-c8ec22b3e787> in <module>
# ----> 1 import cv2
#
# ModuleNotFoundError: No module named 'cv2'

# %%
from matplotlib import pyplot as plt
import numpy as np

# %%
x=np.array([77,57,45,85,40,56,78])
y=np.array([60,75,67,89,59,62,71])
plt.subplot(1,2,1)
plt.plot(x,y)


x=np.array([77,57,65,97,34,85,68])
y=np.array([62,77,59,81,80,30,70])
plt.subplot(1,2,2)
plt.plot(x,y)

plt.show()

# %%
import seaborn
